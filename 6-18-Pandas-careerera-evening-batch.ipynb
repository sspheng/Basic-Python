# %% [markdown]
# ## Bringing | Importing dataset to Python

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/mdarifmokhtar/Desktop/Desktop Stuff/Datasets/pokemon_data.csv")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
new_df = pd.read_excel('/Users/mdarifmokhtar/Desktop/Desktop Stuff/Datasets/Global_Superstore.xlsx')

# %%
pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 KB 3.2 MB/s eta 0:00:00a 0:00:01
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
new_df
# Out:
#        Row ID                  Order ID Order Date  Ship Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
# ...

# %%
new_df_updated = pd.read_excel('/Users/mdarifmokhtar/Desktop/Desktop Stuff/Datasets/Global_Superstore.xlsx', sheet_name= 1)

# %%
new_df_updated
# Out:
#               Unnamed: 0         Unnamed: 1
# 0                 Person             Region
# 1      Marilène Rousseau          Caribbean
# 2       Andile Ihejirika     Central Africa
# 3      Nicodemo Bautista    Central America
# 4         Cansu Peynirci       Central Asia
# 5             Lon Bonher         Central US
# 6           Wasswa Ahmed     Eastern Africa
# 7          Hadia Bousaid       Eastern Asia
# 8         Lynne Marchand     Eastern Canada
# 9          Oxana Lagunov     Eastern Europe
# 10         Dolores Davis         Eastern US
# 11      Lindiwe Afolayan       North Africa
# 12          Miina Nylund    Northern Europe
# 13           Kauri Anaru            Oceania
# 14       Vasco Magalhães      South America
# 15      Preecha Metharom  Southeastern Asia
# 16          Nora Cuijper    Southern Africa
# 17  Chandrakant Chaudhri      Southern Asia
# 18           Gavino Bove    Southern Europe
# 19       Flannery Newton        Southern US
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
x = [1,2,3,4,5,6]

# %%
x[2]
# Out:
# 3

# %%
x[-2]
# Out:
# 5

# %%
df = pd.read_csv('/Users/mdarifmokhtar/Desktop/Desktop Stuff/Datasets/titanic.csv')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
pd.options.display.max_rows = 60

# %%
pd.options.display.min_rows
# Out:
# 10

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
df.head(50)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 0          0       3    male  22.0      1      0    7.2500        S  NaN
# 1          1       1  female  38.0      1      0   71.2833        C    C
# 2          1       3  female  26.0      0      0    7.9250        S  NaN
# 3          1       1  female  35.0      1      0   53.1000        S    C
# 4          0       3    male  35.0      0      0    8.0500        S  NaN
# 5          0       3    male   NaN      0      0    8.4583        Q  NaN
# 6          0       1    male  54.0      0      0   51.8625        S    E
# 7          0       3    male   2.0      3      1   21.0750        S  NaN
# 8          1       3  female  27.0      0      2   11.1333        S  NaN
# 9          1       2  female  14.0      1      0   30.0708        C  NaN
# 10         1       3  female   4.0      1      1   16.7000        S    G
# 11         1       1  female  58.0      0      0   26.5500        S    C
# ...

# %%
df.tail(20)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 871         1       1  female  47.0      1      1  52.5542        S    D
# 872         0       1    male  33.0      0      0   5.0000        S    B
# 873         0       3    male  47.0      0      0   9.0000        S  NaN
# 874         1       2  female  28.0      1      0  24.0000        C  NaN
# 875         1       3  female  15.0      0      0   7.2250        C  NaN
# 876         0       3    male  20.0      0      0   9.8458        S  NaN
# 877         0       3    male  19.0      0      0   7.8958        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 879         1       1  female  56.0      0      1  83.1583        C    C
# 880         1       2  female  25.0      0      1  26.0000        S  NaN
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe(include = 'O')
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
## Creating new column in the dataset - insert(), []
df.insert(6,'Along_with_passenger',df.sibsp+df.parch)

# %%
## Accessing columns from a dataframe
df[['fare','deck']]
# Out:
#         fare deck
# 0     7.2500  NaN
# 1    71.2833    C
# 2     7.9250  NaN
# 3    53.1000    C
# 4     8.0500  NaN
# ..       ...  ...
# 886  13.0000  NaN
# 887  30.0000    B
# 888  23.4500  NaN
# 889  30.0000    C
# 890   7.7500  NaN
#
# [891 rows x 2 columns]

# %%
df.fare
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch  Along_with_passenger  \
# 0           0       3    male  22.0      1      0                     1
# 1           1       1  female  38.0      1      0                     1
# 2           1       3  female  26.0      0      0                     0
# 3           1       1  female  35.0      1      0                     1
# 4           0       3    male  35.0      0      0                     0
# ..        ...     ...     ...   ...    ...    ...                   ...
# 886         0       2    male  27.0      0      0                     0
# 887         1       1  female  19.0      0      0                     0
# 888         0       3  female   NaN      1      2                     3
# 889         1       1    male  26.0      0      0                     0
# 890         0       3    male  32.0      0      0                     0
#
#         fare embarked deck
# 0     7.2500        S  NaN
# 1    71.2833        C    C
# ...

# %%
df['YOB'] = 1912 - df.age

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch  Along_with_passenger  \
# 0           0       3    male  22.0      1      0                     1
# 1           1       1  female  38.0      1      0                     1
# 2           1       3  female  26.0      0      0                     0
# 3           1       1  female  35.0      1      0                     1
# 4           0       3    male  35.0      0      0                     0
# ..        ...     ...     ...   ...    ...    ...                   ...
# 886         0       2    male  27.0      0      0                     0
# 887         1       1  female  19.0      0      0                     0
# 888         0       3  female   NaN      1      2                     3
# 889         1       1    male  26.0      0      0                     0
# 890         0       3    male  32.0      0      0                     0
#
#         fare embarked deck     YOB
# 0     7.2500        S  NaN  1890.0
# ...

# %%
df[['survived','pclass','sex','age','YOB','sibsp','parch','Along_with_passenger','fare','embarked','deck']]
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 1           1       1  female  38.0  1874.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 3           1       1  female  35.0  1877.0      1      0
# 4           0       3    male  35.0  1877.0      0      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 886         0       2    male  27.0  1885.0      0      0
# 887         1       1  female  19.0  1893.0      0      0
# 888         0       3  female   NaN     NaN      1      2
# 889         1       1    male  26.0  1886.0      0      0
# 890         0       3    male  32.0  1880.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 1                       1  71.2833        C    C
# 2                       0   7.9250        S  NaN
# 3                       1  53.1000        S    C
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch  Along_with_passenger  \
# 0           0       3    male  22.0      1      0                     1
# 1           1       1  female  38.0      1      0                     1
# 2           1       3  female  26.0      0      0                     0
# 3           1       1  female  35.0      1      0                     1
# 4           0       3    male  35.0      0      0                     0
# ..        ...     ...     ...   ...    ...    ...                   ...
# 886         0       2    male  27.0      0      0                     0
# 887         1       1  female  19.0      0      0                     0
# 888         0       3  female   NaN      1      2                     3
# 889         1       1    male  26.0      0      0                     0
# 890         0       3    male  32.0      0      0                     0
#
#         fare embarked deck     YOB
# 0     7.2500        S  NaN  1890.0
# ...

# %%
df.columns.values
# Out:
# array(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch',
#        'Along_with_passenger', 'fare', 'embarked', 'deck', 'YOB'],
#       dtype=object)

# %%
cols = list(df.columns.values)

# %%
cols
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'Along_with_passenger',
#  'fare',
#  'embarked',
#  'deck',
#  'YOB']

# %%
cols[0:4]+[cols[-1]]+cols[4:10]
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'YOB',
#  'sibsp',
#  'parch',
#  'Along_with_passenger',
#  'fare',
#  'embarked',
#  'deck']

# %%
cols[0:4]
# Out:
# ['survived', 'pclass', 'sex', 'age']

# %%
cols[4:10]
# Out:
# ['sibsp', 'parch', 'Along_with_passenger', 'fare', 'embarked', 'deck']

# %%
[cols[-1]]
# Out:
# ['YOB']

# %%
df = df[cols[0:4]+ [cols[-1]] + cols[4:10]]

# %%
df
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 1           1       1  female  38.0  1874.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 3           1       1  female  35.0  1877.0      1      0
# 4           0       3    male  35.0  1877.0      0      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 886         0       2    male  27.0  1885.0      0      0
# 887         1       1  female  19.0  1893.0      0      0
# 888         0       3  female   NaN     NaN      1      2
# 889         1       1    male  26.0  1886.0      0      0
# 890         0       3    male  32.0  1880.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 1                       1  71.2833        C    C
# 2                       0   7.9250        S  NaN
# 3                       1  53.1000        S    C
# ...

# %%
cols
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'Along_with_passenger',
#  'fare',
#  'embarked',
#  'deck',
#  'YOB']

# %%
cols[-1]
# Out:
# 'YOB'

# %%
df
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 1           1       1  female  38.0  1874.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 3           1       1  female  35.0  1877.0      1      0
# 4           0       3    male  35.0  1877.0      0      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 886         0       2    male  27.0  1885.0      0      0
# 887         1       1  female  19.0  1893.0      0      0
# 888         0       3  female   NaN     NaN      1      2
# 889         1       1    male  26.0  1886.0      0      0
# 890         0       3    male  32.0  1880.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 1                       1  71.2833        C    C
# 2                       0   7.9250        S  NaN
# 3                       1  53.1000        S    C
# ...

# %%
## Subsetting the data
df_male = df[df['sex']=='male']

# %%
df_male
# Out:
#      survived  pclass   sex   age     YOB  sibsp  parch  Along_with_passenger  \
# 0           0       3  male  22.0  1890.0      1      0                     1
# 4           0       3  male  35.0  1877.0      0      0                     0
# 5           0       3  male   NaN     NaN      0      0                     0
# 6           0       1  male  54.0  1858.0      0      0                     0
# 7           0       3  male   2.0  1910.0      3      1                     4
# ..        ...     ...   ...   ...     ...    ...    ...                   ...
# 883         0       2  male  28.0  1884.0      0      0                     0
# 884         0       3  male  25.0  1887.0      0      0                     0
# 886         0       2  male  27.0  1885.0      0      0                     0
# 889         1       1  male  26.0  1886.0      0      0                     0
# 890         0       3  male  32.0  1880.0      0      0                     0
#
#         fare embarked deck
# ...

# %%
df_female_kid = df[(df['sex']=='female') | (df['age']<=18)]

# %%
df_female_kid
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 1           1       1  female  38.0  1874.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 3           1       1  female  35.0  1877.0      1      0
# 7           0       3    male   2.0  1910.0      3      1
# 8           1       3  female  27.0  1885.0      0      2
# ..        ...     ...     ...   ...     ...    ...    ...
# 880         1       2  female  25.0  1887.0      0      1
# 882         0       3  female  22.0  1890.0      0      0
# 885         0       3  female  39.0  1873.0      0      5
# 887         1       1  female  19.0  1893.0      0      0
# 888         0       3  female   NaN     NaN      1      2
#
#      Along_with_passenger     fare embarked deck
# 1                       1  71.2833        C    C
# 2                       0   7.9250        S  NaN
# 3                       1  53.1000        S    C
# 7                       4  21.0750        S  NaN
# ...

# %%
df
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 1           1       1  female  38.0  1874.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 3           1       1  female  35.0  1877.0      1      0
# 4           0       3    male  35.0  1877.0      0      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 886         0       2    male  27.0  1885.0      0      0
# 887         1       1  female  19.0  1893.0      0      0
# 888         0       3  female   NaN     NaN      1      2
# 889         1       1    male  26.0  1886.0      0      0
# 890         0       3    male  32.0  1880.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 1                       1  71.2833        C    C
# 2                       0   7.9250        S  NaN
# 3                       1  53.1000        S    C
# ...

# %%
new_df = df[['survived','age','YOB','embarked']]

# %%
new_df
# Out:
#      survived   age     YOB embarked
# 0           0  22.0  1890.0        S
# 1           1  38.0  1874.0        C
# 2           1  26.0  1886.0        S
# 3           1  35.0  1877.0        S
# 4           0  35.0  1877.0        S
# ..        ...   ...     ...      ...
# 886         0  27.0  1885.0        S
# 887         1  19.0  1893.0        S
# 888         0   NaN     NaN        S
# 889         1  26.0  1886.0        C
# 890         0  32.0  1880.0        Q
#
# [891 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   survived              891 non-null    int64
#  1   pclass                891 non-null    int64
#  2   sex                   891 non-null    object
#  3   age                   714 non-null    float64
#  4   YOB                   714 non-null    float64
#  5   sibsp                 891 non-null    int64
#  6   parch                 891 non-null    int64
#  7   Along_with_passenger  891 non-null    int64
#  8   fare                  891 non-null    float64
#  9   embarked              889 non-null    object
#  10  deck                  203 non-null    object
# dtypes: float64(3), int64(5), object(3)
# memory usage: 76.7+ KB

# %%
df.dtypes
# Out:
# survived                  int64
# pclass                    int64
# sex                      object
# age                     float64
# YOB                     float64
# sibsp                     int64
# parch                     int64
# Along_with_passenger      int64
# fare                    float64
# embarked                 object
# deck                     object
# dtype: object

# %%
df.select_dtypes(include = ['int','float'])
# Out:
#      survived  pclass   age     YOB  sibsp  parch  Along_with_passenger  \
# 0           0       3  22.0  1890.0      1      0                     1
# 1           1       1  38.0  1874.0      1      0                     1
# 2           1       3  26.0  1886.0      0      0                     0
# 3           1       1  35.0  1877.0      1      0                     1
# 4           0       3  35.0  1877.0      0      0                     0
# ..        ...     ...   ...     ...    ...    ...                   ...
# 886         0       2  27.0  1885.0      0      0                     0
# 887         1       1  19.0  1893.0      0      0                     0
# 888         0       3   NaN     NaN      1      2                     3
# 889         1       1  26.0  1886.0      0      0                     0
# 890         0       3  32.0  1880.0      0      0                     0
#
#         fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# ...

# %%
df.pclass.nunique()
# Out:
# 3

# %%
df.pclass.unique()
# Out:
# array([3, 1, 2])

# %%
df['pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
df.pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
df['pclass'].count()
# Out:
# 891

# %%
df['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
# ...

# %%
print('Hi')
# Out:
# Hi

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/mdarifmokhtar/Desktop'

# %%
df_female_kid = df[(df['sex']=='female') | (df['age']<=18)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:301, in na_logical_op(x, y, op)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/ops/array_ops.py?line=291'>292</a> try:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/ops/array_ops.py?line=292'>293</a>     # For exposition, write:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/ops/array_ops.py?line=293'>294</a>     #  yarr = isinstance(y, np.ndarray)
#    (...)
# ...

# %%
df
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 1           1       1  female  38.0  1874.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 3           1       1  female  35.0  1877.0      1      0
# 4           0       3    male  35.0  1877.0      0      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 886         0       2    male  27.0  1885.0      0      0
# 887         1       1  female  19.0  1893.0      0      0
# 888         0       3  female   NaN     NaN      1      2
# 889         1       1    male  26.0  1886.0      0      0
# 890         0       3    male  32.0  1880.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 1                       1  71.2833        C    C
# 2                       0   7.9250        S  NaN
# 3                       1  53.1000        S    C
# ...

# %%
df[(df['age'] >= 20) & (df['age'] <30)]
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 8           1       3  female  27.0  1885.0      0      2
# 23          1       1    male  28.0  1884.0      0      0
# 34          0       1    male  28.0  1884.0      1      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 882         0       3  female  22.0  1890.0      0      0
# 883         0       2    male  28.0  1884.0      0      0
# 884         0       3    male  25.0  1887.0      0      0
# 886         0       2    male  27.0  1885.0      0      0
# 889         1       1    male  26.0  1886.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 2                       0   7.9250        S  NaN
# 8                       2  11.1333        S  NaN
# 23                      0  35.5000        S    A
# ...

# %%
df[df.age.between(20,30)]
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 8           1       3  female  27.0  1885.0      0      2
# 12          0       3    male  20.0  1892.0      0      0
# 23          1       1    male  28.0  1884.0      0      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 882         0       3  female  22.0  1890.0      0      0
# 883         0       2    male  28.0  1884.0      0      0
# 884         0       3    male  25.0  1887.0      0      0
# 886         0       2    male  27.0  1885.0      0      0
# 889         1       1    male  26.0  1886.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 2                       0   7.9250        S  NaN
# 8                       2  11.1333        S  NaN
# 12                      0   8.0500        S  NaN
# ...

# %%
df[df.age.between(20,30, inclusive=False)]
# Out:
# /var/folders/np/z13y5s3n2jlc7d6fgfm132gm0000gn/T/ipykernel_60456/286527923.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df[df.age.between(20,30, inclusive=False)]
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 8           1       3  female  27.0  1885.0      0      2
# 23          1       1    male  28.0  1884.0      0      0
# 34          0       1    male  28.0  1884.0      1      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 882         0       3  female  22.0  1890.0      0      0
# 883         0       2    male  28.0  1884.0      0      0
# 884         0       3    male  25.0  1887.0      0      0
# 886         0       2    male  27.0  1885.0      0      0
# 889         1       1    male  26.0  1886.0      0      0
#
# ...

# %%
df[((df.age.between(20,30) & (df.pclass.between(1,2)) | (df.fare > 21)))]
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 1           1       1  female  38.0  1874.0      1      0
# 3           1       1  female  35.0  1877.0      1      0
# 6           0       1    male  54.0  1858.0      0      0
# 7           0       3    male   2.0  1910.0      3      1
# 9           1       2  female  14.0  1898.0      1      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 885         0       3  female  39.0  1873.0      0      5
# 886         0       2    male  27.0  1885.0      0      0
# 887         1       1  female  19.0  1893.0      0      0
# 888         0       3  female   NaN     NaN      1      2
# 889         1       1    male  26.0  1886.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 1                       1  71.2833        C    C
# 3                       1  53.1000        S    C
# 6                       0  51.8625        S    E
# 7                       4  21.0750        S  NaN
# ...

# %%
df.deck.nunique()
# Out:
# 7

# %%
df[(df.age.between(20,30)) & (df.pclass.between(1,2))]
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 23          1       1    male  28.0  1884.0      0      0
# 34          0       1    male  28.0  1884.0      1      0
# 41          0       2  female  27.0  1885.0      1      0
# 53          1       2  female  29.0  1883.0      1      0
# 56          1       2  female  21.0  1891.0      0      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 874         1       2  female  28.0  1884.0      1      0
# 880         1       2  female  25.0  1887.0      0      1
# 883         0       2    male  28.0  1884.0      0      0
# 886         0       2    male  27.0  1885.0      0      0
# 889         1       1    male  26.0  1886.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 23                      0  35.5000        S    A
# 34                      1  82.1708        C  NaN
# 41                      1  21.0000        S  NaN
# 53                      1  26.0000        S  NaN
# ...

# %%
df[(df.age.between(20,30)) & (df.pclass.between(1,2)) & (df.fare > 21)]
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 23          1       1    male  28.0  1884.0      0      0
# 34          0       1    male  28.0  1884.0      1      0
# 53          1       2  female  29.0  1883.0      1      0
# 72          0       2    male  21.0  1891.0      0      0
# 83          0       1    male  28.0  1884.0      0      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 842         1       1  female  30.0  1882.0      0      0
# 848         0       2    male  28.0  1884.0      0      1
# 874         1       2  female  28.0  1884.0      1      0
# 880         1       2  female  25.0  1887.0      0      1
# 889         1       1    male  26.0  1886.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 23                      0  35.5000        S    A
# 34                      1  82.1708        C  NaN
# 53                      1  26.0000        S  NaN
# 72                      0  73.5000        S  NaN
# ...

# %%
df.deck.nunique()
# Out:
# 7

# %%
df.deck.unique()
# Out:
# array([nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F'], dtype=object)

# %%
df[(df.deck == 'A') | (df.deck == 'B') | (df.deck== 'C')]
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 1           1       1  female  38.0  1874.0      1      0
# 3           1       1  female  35.0  1877.0      1      0
# 11          1       1  female  58.0  1854.0      0      0
# 23          1       1    male  28.0  1884.0      0      0
# 27          0       1    male  19.0  1893.0      3      2
# ..        ...     ...     ...   ...     ...    ...    ...
# 867         0       1    male  31.0  1881.0      0      0
# 872         0       1    male  33.0  1879.0      0      0
# 879         1       1  female  56.0  1856.0      0      1
# 887         1       1  female  19.0  1893.0      0      0
# 889         1       1    male  26.0  1886.0      0      0
#
#      Along_with_passenger      fare embarked deck
# 1                       1   71.2833        C    C
# 3                       1   53.1000        S    C
# 11                      0   26.5500        S    C
# 23                      0   35.5000        S    A
# ...

# %%
deck = ['A','B','C']

# %%
df[df.deck.isin(deck)]
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 1           1       1  female  38.0  1874.0      1      0
# 3           1       1  female  35.0  1877.0      1      0
# 11          1       1  female  58.0  1854.0      0      0
# 23          1       1    male  28.0  1884.0      0      0
# 27          0       1    male  19.0  1893.0      3      2
# ..        ...     ...     ...   ...     ...    ...    ...
# 867         0       1    male  31.0  1881.0      0      0
# 872         0       1    male  33.0  1879.0      0      0
# 879         1       1  female  56.0  1856.0      0      1
# 887         1       1  female  19.0  1893.0      0      0
# 889         1       1    male  26.0  1886.0      0      0
#
#      Along_with_passenger      fare embarked deck
# 1                       1   71.2833        C    C
# 3                       1   53.1000        S    C
# 11                      0   26.5500        S    C
# 23                      0   35.5000        S    A
# ...

# %%
df.deck.unique()
# Out:
# array([nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F'], dtype=object)

# %%
deck
# Out:
# ['A', 'B', 'C']

# %%
df[~df.deck.isin(deck)]
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 4           0       3    male  35.0  1877.0      0      0
# 5           0       3    male   NaN     NaN      0      0
# 6           0       1    male  54.0  1858.0      0      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 884         0       3    male  25.0  1887.0      0      0
# 885         0       3  female  39.0  1873.0      0      5
# 886         0       2    male  27.0  1885.0      0      0
# 888         0       3  female   NaN     NaN      1      2
# 890         0       3    male  32.0  1880.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 2                       0   7.9250        S  NaN
# 4                       0   8.0500        S  NaN
# 5                       0   8.4583        Q  NaN
# ...

# %%
df[df.deck.notin(deck)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/mdarifmokhtar/Desktop/Pandas Careerera Evening batch.ipynb Cell 82' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mdarifmokhtar/Desktop/Pandas%20Careerera%20Evening%20batch.ipynb#ch0000095?line=0'>1</a> df[df.deck.notin(deck)]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py?line=5567'>5568</a> if (
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py?line=5568'>5569</a>     name not in self._internal_names_set
# ...

# %%
## Handling Missing Values (isnull, isna)
df
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 1           1       1  female  38.0  1874.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 3           1       1  female  35.0  1877.0      1      0
# 4           0       3    male  35.0  1877.0      0      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 886         0       2    male  27.0  1885.0      0      0
# 887         1       1  female  19.0  1893.0      0      0
# 888         0       3  female   NaN     NaN      1      2
# 889         1       1    male  26.0  1886.0      0      0
# 890         0       3    male  32.0  1880.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 1                       1  71.2833        C    C
# 2                       0   7.9250        S  NaN
# 3                       1  53.1000        S    C
# ...

# %%
df[df['deck'].isna()]
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 4           0       3    male  35.0  1877.0      0      0
# 5           0       3    male   NaN     NaN      0      0
# 7           0       3    male   2.0  1910.0      3      1
# ..        ...     ...     ...   ...     ...    ...    ...
# 884         0       3    male  25.0  1887.0      0      0
# 885         0       3  female  39.0  1873.0      0      5
# 886         0       2    male  27.0  1885.0      0      0
# 888         0       3  female   NaN     NaN      1      2
# 890         0       3    male  32.0  1880.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 2                       0   7.9250        S  NaN
# 4                       0   8.0500        S  NaN
# 5                       0   8.4583        Q  NaN
# ...

# %%
df[df['deck'].isnull()]
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 4           0       3    male  35.0  1877.0      0      0
# 5           0       3    male   NaN     NaN      0      0
# 7           0       3    male   2.0  1910.0      3      1
# ..        ...     ...     ...   ...     ...    ...    ...
# 884         0       3    male  25.0  1887.0      0      0
# 885         0       3  female  39.0  1873.0      0      5
# 886         0       2    male  27.0  1885.0      0      0
# 888         0       3  female   NaN     NaN      1      2
# 890         0       3    male  32.0  1880.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 2                       0   7.9250        S  NaN
# 4                       0   8.0500        S  NaN
# 5                       0   8.4583        Q  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   survived              891 non-null    int64
#  1   pclass                891 non-null    int64
#  2   sex                   891 non-null    object
#  3   age                   714 non-null    float64
#  4   YOB                   714 non-null    float64
#  5   sibsp                 891 non-null    int64
#  6   parch                 891 non-null    int64
#  7   Along_with_passenger  891 non-null    int64
#  8   fare                  891 non-null    float64
#  9   embarked              889 non-null    object
#  10  deck                  203 non-null    object
# dtypes: float64(3), int64(5), object(3)
# memory usage: 76.7+ KB

# %%
df.isnull().sum()
# Out:
# survived                  0
# pclass                    0
# sex                       0
# age                     177
# YOB                     177
# sibsp                     0
# parch                     0
# Along_with_passenger      0
# fare                      0
# embarked                  2
# deck                    688
# dtype: int64

# %%
df[df.deck.isna()]
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 4           0       3    male  35.0  1877.0      0      0
# 5           0       3    male   NaN     NaN      0      0
# 7           0       3    male   2.0  1910.0      3      1
# ..        ...     ...     ...   ...     ...    ...    ...
# 884         0       3    male  25.0  1887.0      0      0
# 885         0       3  female  39.0  1873.0      0      5
# 886         0       2    male  27.0  1885.0      0      0
# 888         0       3  female   NaN     NaN      1      2
# 890         0       3    male  32.0  1880.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 2                       0   7.9250        S  NaN
# 4                       0   8.0500        S  NaN
# 5                       0   8.4583        Q  NaN
# ...

# %%
df[df.deck =='A']
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 23          1       1    male  28.0  1884.0      0      0
# 96          0       1    male  71.0  1841.0      0      0
# 174         0       1    male  56.0  1856.0      0      0
# 185         0       1    male   NaN     NaN      0      0
# 209         1       1    male  40.0  1872.0      0      0
# 284         0       1    male   NaN     NaN      0      0
# 445         1       1    male   4.0  1908.0      0      2
# 475         0       1    male   NaN     NaN      0      0
# 556         1       1  female  48.0  1864.0      1      0
# 583         0       1    male  36.0  1876.0      0      0
# 599         1       1    male  49.0  1863.0      1      0
# 630         1       1    male  80.0  1832.0      0      0
# 647         1       1    male  56.0  1856.0      0      0
# 806         0       1    male  39.0  1873.0      0      0
# 867         0       1    male  31.0  1881.0      0      0
#
# ...

# %%
i am not getting answer for following question can you plz check the code and let me know where I did the mistake

Write a program to accept two numbers and a mathematical operators and perform operation accordingly
x=int(input("enter number1"))
y=int(input("enter number2"))
mp=input("enter the mathamatical operator")
if mp== "+":
    print("the sum of two numbers=", x+y)
elif mp== "-":
   z=input("x-y or y-z: ")
if z==x-y or z==y-x:
    print("the difference between two numbers=", x-y)
else:
    print("the difference between two numbers=", y-x)
​
elif mp== "*":
    print("Multiplication of two numbers=", x*y)
elif mp== "%":
    z=input("x%y or y%x: ")
    if z==x%y or z==y%x
    print("reminder of division=", x%y)
    else:
        print("reminder of the division is", y%x)
elif mp== "/":
    z=input(z==x/y or z==y/z)
    if z==x%y or z==y%x
    print("quotient of division=", z)
    else:
        print(quotient of division=", z)

# %%
## Handling the missing values

# %%
df
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 1           1       1  female  38.0  1874.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 3           1       1  female  35.0  1877.0      1      0
# 4           0       3    male  35.0  1877.0      0      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 886         0       2    male  27.0  1885.0      0      0
# 887         1       1  female  19.0  1893.0      0      0
# 888         0       3  female   NaN     NaN      1      2
# 889         1       1    male  26.0  1886.0      0      0
# 890         0       3    male  32.0  1880.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 1                       1  71.2833        C    C
# 2                       0   7.9250        S  NaN
# 3                       1  53.1000        S    C
# ...

# %%
df['age'].fillna(20, inplace = True )
# Out:
# /var/folders/np/z13y5s3n2jlc7d6fgfm132gm0000gn/T/ipykernel_60456/4064068098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age'].fillna(20, inplace = True )

# %%
df
# Out:
#      survived  pclass     sex   age     YOB  sibsp  parch  \
# 0           0       3    male  22.0  1890.0      1      0
# 1           1       1  female  38.0  1874.0      1      0
# 2           1       3  female  26.0  1886.0      0      0
# 3           1       1  female  35.0  1877.0      1      0
# 4           0       3    male  35.0  1877.0      0      0
# ..        ...     ...     ...   ...     ...    ...    ...
# 886         0       2    male  27.0  1885.0      0      0
# 887         1       1  female  19.0  1893.0      0      0
# 888         0       3  female  20.0     NaN      1      2
# 889         1       1    male  26.0  1886.0      0      0
# 890         0       3    male  32.0  1880.0      0      0
#
#      Along_with_passenger     fare embarked deck
# 0                       1   7.2500        S  NaN
# 1                       1  71.2833        C    C
# 2                       0   7.9250        S  NaN
# 3                       1  53.1000        S    C
# ...

# %%
df['age'].mean()
# Out:
# 29.69911764705882

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df['age'].fillna(df['age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
df['age'].mean()
# Out:
# 29.69911764705882

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df[{'age':'deck'}].fillna({20:'C'})
# Out:
# /var/folders/np/z13y5s3n2jlc7d6fgfm132gm0000gn/T/ipykernel_60456/2745570609.py:1: FutureWarning: Passing a dict as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[{'age':'deck'}].fillna({20:'C'})
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
df.fillna({'age':20,'deck':'C'})
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S    C
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S    C
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S    C
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S    C
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female  20.0      1      2  23.4500        S    C
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q    C
#
# [891 rows x 9 columns]

# %%
df[{'age':20,'deck':'C'}].fillna()
# Out:
# /var/folders/np/z13y5s3n2jlc7d6fgfm132gm0000gn/T/ipykernel_60456/1558472754.py:1: FutureWarning: Passing a dict as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[{'age':20,'deck':'C'}].fillna()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/mdarifmokhtar/Desktop/Pandas Careerera Evening batch.ipynb Cell 103' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mdarifmokhtar/Desktop/Pandas%20Careerera%20Evening%20batch.ipynb#ch0000118?line=0'>1</a> df[{'age':20,'deck':'C'}].fillna()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
df['age','deck'].fillna({'age':20,'deck':'C'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df['age'].fillna(method = 'ffill')
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df['age'].fillna(method = 'bfill')
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    26.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df['age'].fillna(method = 'ffill', limit = 1)
# Out:
# 0      22.00
# 1      38.00
# 2      26.00
# 3      35.00
# 4      35.00
# 5      35.00
# 6      54.00
# 7       2.00
# 8      27.00
# 9      14.00
# 10      4.00
# 11     58.00
# 12     20.00
# 13     39.00
# 14     14.00
# 15     55.00
# 16      2.00
# 17      2.00
# 18     31.00
# 19     31.00
# 20     35.00
# 21     34.00
# 22     15.00
# 23     28.00
# 24      8.00
# 25     38.00
# 26     38.00
# 27     19.00
# 28     19.00
# 29       NaN
# 30     40.00
# 31     40.00
# 32       NaN
# 33     66.00
# 34     28.00
# 35     42.00
# 36     42.00
# 37     21.00
# 38     18.00
# 39     14.00
# 40     40.00
# 41     27.00
# 42     27.00
# 43      3.00
# 44     19.00
# 45     19.00
# 46       NaN
# 47       NaN
# 48       NaN
# 49     18.00
# 50      7.00
# 51     21.00
# 52     49.00
# 53     29.00
# 54     65.00
# 55     65.00
# 56     21.00
# 57     28.50
# 58      5.00
# 59     11.00
# 60     22.00
# 61     38.00
# 62     45.00
# 63      4.00
# 64      4.00
# 65       NaN
# ...

# %%
df['age'].fillna(method = 'bfill', limit = 1)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    26.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
pd.options.display.max_rows = 60

# %%
df['age'].fillna(20, limit = 1)
# Out:
# 0      22.00
# 1      38.00
# 2      26.00
# 3      35.00
# 4      35.00
# 5      20.00
# 6      54.00
# 7       2.00
# 8      27.00
# 9      14.00
# 10      4.00
# 11     58.00
# 12     20.00
# 13     39.00
# 14     14.00
# 15     55.00
# 16      2.00
# 17       NaN
# 18     31.00
# 19       NaN
# 20     35.00
# 21     34.00
# 22     15.00
# 23     28.00
# 24      8.00
# 25     38.00
# 26       NaN
# 27     19.00
# 28       NaN
# 29       NaN
# 30     40.00
# 31       NaN
# 32       NaN
# 33     66.00
# 34     28.00
# 35     42.00
# 36       NaN
# 37     21.00
# 38     18.00
# 39     14.00
# 40     40.00
# 41     27.00
# 42       NaN
# 43      3.00
# 44     19.00
# 45       NaN
# 46       NaN
# 47       NaN
# 48       NaN
# 49     18.00
# 50      7.00
# 51     21.00
# 52     49.00
# 53     29.00
# 54     65.00
# 55       NaN
# 56     21.00
# 57     28.50
# 58      5.00
# 59     11.00
# 60     22.00
# 61     38.00
# 62     45.00
# 63      4.00
# 64       NaN
# 65       NaN
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
## Deleting columns from dataframe
df.drop(['fare'], axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch embarked deck
# 0           0       3    male  22.0      1      0        S  NaN
# 1           1       1  female  38.0      1      0        C    C
# 2           1       3  female  26.0      0      0        S  NaN
# 3           1       1  female  35.0      1      0        S    C
# 4           0       3    male  35.0      0      0        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...  ...
# 886         0       2    male  27.0      0      0        S  NaN
# 887         1       1  female  19.0      0      0        S    B
# 888         0       3  female   NaN      1      2        S  NaN
# 889         1       1    male  26.0      0      0        C    C
# 890         0       3    male  32.0      0      0        Q  NaN
#
# [891 rows x 8 columns]

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.drop(['fare'],axis = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/mdarifmokhtar/Desktop/Pandas Careerera Evening batch.ipynb Cell 115' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mdarifmokhtar/Desktop/Pandas%20Careerera%20Evening%20batch.ipynb#ch0000128?line=0'>1</a> df.drop(['fare'],axis = 0)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.drop(df.columns[[0,6]], axis = 1)
# Out:
#      pclass     sex   age  sibsp  parch embarked deck
# 0         3    male  22.0      1      0        S  NaN
# 1         1  female  38.0      1      0        C    C
# 2         3  female  26.0      0      0        S  NaN
# 3         1  female  35.0      1      0        S    C
# 4         3    male  35.0      0      0        S  NaN
# ..      ...     ...   ...    ...    ...      ...  ...
# 886       2    male  27.0      0      0        S  NaN
# 887       1  female  19.0      0      0        S    B
# 888       3  female   NaN      1      2        S  NaN
# 889       1    male  26.0      0      0        C    C
# 890       3    male  32.0      0      0        Q  NaN
#
# [891 rows x 7 columns]

# %%
for i in df.age:
    print(i)
# Out:
# 22.0
# 38.0
# 26.0
# 35.0
# 35.0
# nan
# 54.0
# 2.0
# 27.0
# 14.0
# 4.0
# 58.0
# 20.0
# 39.0
# 14.0
# 55.0
# 2.0
# nan
# 31.0
# nan
# 35.0
# 34.0
# 15.0
# 28.0
# 8.0
# 38.0
# nan
# 19.0
# nan
# nan
# 40.0
# nan
# nan
# 66.0
# 28.0
# 42.0
# nan
# 21.0
# 18.0
# 14.0
# 40.0
# 27.0
# nan
# 3.0
# 19.0
# nan
# nan
# nan
# nan
# 18.0
# 7.0
# 21.0
# 49.0
# 29.0
# 65.0
# nan
# 21.0
# 28.5
# 5.0
# 11.0
# 22.0
# 38.0
# 45.0
# 4.0
# nan
# nan
# 29.0
# 19.0
# 17.0
# 26.0
# 32.0
# 16.0
# 21.0
# 26.0
# 32.0
# 25.0
# nan
# nan
# 0.83
# 30.0
# 22.0
# 29.0
# nan
# 28.0
# 17.0
# 33.0
# 16.0
# nan
# 23.0
# 24.0
# 29.0
# 20.0
# 46.0
# 26.0
# 59.0
# nan
# 71.0
# 23.0
# 34.0
# 34.0
# 28.0
# nan
# 21.0
# 33.0
# 37.0
# 28.0
# 21.0
# nan
# 38.0
# nan
# 47.0
# 14.5
# 22.0
# 20.0
# 17.0
# 21.0
# 70.5
# 29.0
# 24.0
# 2.0
# 21.0
# nan
# 32.5
# 32.5
# 54.0
# 12.0
# nan
# 24.0
# nan
# 45.0
# 33.0
# 20.0
# 47.0
# 29.0
# 25.0
# 23.0
# 19.0
# 37.0
# 16.0
# 24.0
# nan
# 22.0
# 24.0
# 19.0
# 18.0
# 19.0
# 27.0
# 9.0
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df[['pclass','fare', 'deck','sex']]
# Out:
#      pclass     fare deck     sex
# 0         3   7.2500  NaN    male
# 1         1  71.2833    C  female
# 2         3   7.9250  NaN  female
# 3         1  53.1000    C  female
# 4         3   8.0500  NaN    male
# ..      ...      ...  ...     ...
# 886       2  13.0000  NaN    male
# 887       1  30.0000    B  female
# 888       3  23.4500  NaN  female
# 889       1  30.0000    C    male
# 890       3   7.7500  NaN    male
#
# [891 rows x 4 columns]

# %%
x = [1,2,4,4,5,6,7,8]

# %%
x = 10,20,30

# %%
x
# Out:
# (10, 20, 30)

# %%
df[['pclass','fare', 'deck','sex']]
# Out:
#      pclass     fare deck     sex
# 0         3   7.2500  NaN    male
# 1         1  71.2833    C  female
# 2         3   7.9250  NaN  female
# 3         1  53.1000    C  female
# 4         3   8.0500  NaN    male
# ..      ...      ...  ...     ...
# 886       2  13.0000  NaN    male
# 887       1  30.0000    B  female
# 888       3  23.4500  NaN  female
# 889       1  30.0000    C    male
# 890       3   7.7500  NaN    male
#
# [891 rows x 4 columns]

# %%
##Rows and Columns - iloc and loc(pandas)

# %%
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male   NaN      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.iloc[10:30,[0,1,3]]
# Out:
#     survived  pclass   age
# 10         1       3   4.0
# 11         1       1  58.0
# 12         0       3  20.0
# 13         0       3  39.0
# 14         0       3  14.0
# 15         1       2  55.0
# 16         0       3   2.0
# 17         1       2   NaN
# 18         0       3  31.0
# 19         1       3   NaN
# 20         0       2  35.0
# 21         1       2  34.0
# 22         1       3  15.0
# 23         1       1  28.0
# 24         0       3   8.0
# 25         1       3  38.0
# 26         0       3   NaN
# 27         0       1  19.0
# 28         1       3   NaN
# 29         0       3   NaN

# %%
df.iloc[10:30,0:5]
# Out:
#     survived  pclass     sex   age  sibsp
# 10         1       3  female   4.0      1
# 11         1       1  female  58.0      0
# 12         0       3    male  20.0      0
# 13         0       3    male  39.0      1
# 14         0       3  female  14.0      0
# 15         1       2  female  55.0      0
# 16         0       3    male   2.0      4
# 17         1       2    male   NaN      0
# 18         0       3  female  31.0      1
# 19         1       3  female   NaN      0
# 20         0       2    male  35.0      0
# 21         1       2    male  34.0      0
# 22         1       3  female  15.0      0
# 23         1       1    male  28.0      0
# 24         0       3  female   8.0      3
# 25         1       3  female  38.0      1
# 26         0       3    male   NaN      0
# 27         0       1    male  19.0      3
# 28         1       3  female   NaN      0
# 29         0       3    male   NaN      0

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.iloc[10:30,['survived','pclass','age']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/mdarifmokhtar/Desktop/Pandas Careerera Evening batch.ipynb Cell 130' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mdarifmokhtar/Desktop/Pandas%20Careerera%20Evening%20batch.ipynb#ch0000143?line=0'>1</a> df.iloc[10:30,['survived','pclass','age']]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py?line=958'>959</a>     if self._is_scalar_access(key):
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py?line=959'>960</a>         return self.obj._get_value(*key, takeable=self._takeable)
# ...

# %%
df.loc[10:30,['survived','pclass','age']]
# Out:
#     survived  pclass   age
# 10         1       3   4.0
# 11         1       1  58.0
# 12         0       3  20.0
# 13         0       3  39.0
# 14         0       3  14.0
# 15         1       2  55.0
# 16         0       3   2.0
# 17         1       2   NaN
# 18         0       3  31.0
# 19         1       3   NaN
# 20         0       2  35.0
# 21         1       2  34.0
# 22         1       3  15.0
# 23         1       1  28.0
# 24         0       3   8.0
# 25         1       3  38.0
# 26         0       3   NaN
# 27         0       1  19.0
# 28         1       3   NaN
# 29         0       3   NaN
# 30         0       1  40.0

# %%
df.iloc[:,0:4]
# Out:
#      survived  pclass     sex   age
# 0           0       3    male  22.0
# 1           1       1  female  38.0
# 2           1       3  female  26.0
# 3           1       1  female  35.0
# 4           0       3    male  35.0
# ..        ...     ...     ...   ...
# 886         0       2    male  27.0
# 887         1       1  female  19.0
# 888         0       3  female   NaN
# 889         1       1    male  26.0
# 890         0       3    male  32.0
#
# [891 rows x 4 columns]

# %%
df.iloc[5:,0:4]
# Out:
#      survived  pclass     sex   age
# 5           0       3    male   NaN
# 6           0       1    male  54.0
# 7           0       3    male   2.0
# 8           1       3  female  27.0
# 9           1       2  female  14.0
# ..        ...     ...     ...   ...
# 886         0       2    male  27.0
# 887         1       1  female  19.0
# 888         0       3  female   NaN
# 889         1       1    male  26.0
# 890         0       3    male  32.0
#
# [886 rows x 4 columns]

# %%
df.iloc[0:10]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %%
df.iloc[:10,0:4]
# Out:
#    survived  pclass     sex   age
# 0         0       3    male  22.0
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 4         0       3    male  35.0
# 5         0       3    male   NaN
# 6         0       1    male  54.0
# 7         0       3    male   2.0
# 8         1       3  female  27.0
# 9         1       2  female  14.0

# %%
df.iloc[:10,3:]
# Out:
#     age  sibsp  parch     fare embarked deck
# 0  22.0      1      0   7.2500        S  NaN
# 1  38.0      1      0  71.2833        C    C
# 2  26.0      0      0   7.9250        S  NaN
# 3  35.0      1      0  53.1000        S    C
# 4  35.0      0      0   8.0500        S  NaN
# 5   NaN      0      0   8.4583        Q  NaN
# 6  54.0      0      0  51.8625        S    E
# 7   2.0      3      1  21.0750        S  NaN
# 8  27.0      0      2  11.1333        S  NaN
# 9  14.0      1      0  30.0708        C  NaN

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
## Sorting the data
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.sort_values(by = 'fare')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 271         1       3    male  25.0      0      0    0.0000        S  NaN
# 597         0       3    male  49.0      0      0    0.0000        S  NaN
# 302         0       3    male  19.0      0      0    0.0000        S  NaN
# 633         0       1    male   NaN      0      0    0.0000        S  NaN
# 277         0       2    male   NaN      0      0    0.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 438         0       1    male  64.0      1      4  263.0000        S    C
# 341         1       1  female  24.0      3      2  263.0000        S    C
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 679         1       1    male  36.0      0      1  512.3292        C    B
#
# [891 rows x 9 columns]

# %%
df.sort_values(by = ['pclass','sex','age'])
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 297         0       1  female   2.00      1      2  151.5500        S    C
# 435         1       1  female  14.00      1      2  120.0000        S    B
# 689         1       1  female  15.00      0      1  211.3375        S    B
# 329         1       1  female  16.00      0      1   57.9792        C    B
# 504         1       1  female  16.00      0      0   86.5000        S    B
# 853         1       1  female  16.00      0      1   39.4000        S    D
# 307         1       1  female  17.00      1      0  108.9000        C    C
# 781         1       1  female  17.00      1      0   57.0000        S    B
# 311         1       1  female  18.00      2      2  262.3750        C    B
# 585         1       1  female  18.00      0      2   79.6500        S    E
# 700         1       1  female  18.00      1      0  227.5250        C    C
# ...

# %%
pd.options.display.max_rows = 900

# %%
df.sort_values(by = ['pclass','sex','age'], ascending = False)
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 851         0       3    male  74.00      0      0    7.7750        S  NaN
# 116         0       3    male  70.50      0      0    7.7500        Q  NaN
# 280         0       3    male  65.00      0      0    7.7500        Q  NaN
# 326         0       3    male  61.00      0      0    6.2375        S  NaN
# 94          0       3    male  59.00      0      0    7.2500        S  NaN
# 152         0       3    male  55.50      0      0    8.0500        S  NaN
# 222         0       3    male  51.00      0      0    8.0500        S  NaN
# 406         0       3    male  51.00      0      0    7.7500        S  NaN
# 631         0       3    male  51.00      0      0    7.0542        S  NaN
# 482         0       3    male  50.00      0      0    8.0500        S  NaN
# 597         0       3    male  49.00      0      0    0.0000        S  NaN
# ...

# %%
df.sort_values(by = ['pclass','sex','age'], ascending = [1,0,1], inplace = True)

# %%
df
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 305         1       1    male   0.92      1      2  151.5500        S    C
# 445         1       1    male   4.00      0      2   81.8583        S    A
# 802         1       1    male  11.00      1      2  120.0000        S    B
# 550         1       1    male  17.00      0      2  110.8833        C    C
# 505         0       1    male  18.00      1      0  108.9000        C    C
# 27          0       1    male  19.00      3      2  263.0000        S    C
# 748         0       1    male  19.00      1      0   53.1000        S    D
# 102         0       1    male  21.00      0      1   77.2875        S    D
# 373         0       1    male  22.00      0      0  135.6333        C  NaN
# 97          1       1    male  23.00      0      1   63.3583        C    D
# 118         0       1    male  24.00      0      1  247.5208        C    B
# ...

# %%
df.iloc[0:10,:]
# Out:
#      survived  pclass   sex    age  sibsp  parch      fare embarked deck
# 305         1       1  male   0.92      1      2  151.5500        S    C
# 445         1       1  male   4.00      0      2   81.8583        S    A
# 802         1       1  male  11.00      1      2  120.0000        S    B
# 550         1       1  male  17.00      0      2  110.8833        C    C
# 505         0       1  male  18.00      1      0  108.9000        C    C
# 27          0       1  male  19.00      3      2  263.0000        S    C
# 748         0       1  male  19.00      1      0   53.1000        S    D
# 102         0       1  male  21.00      0      1   77.2875        S    D
# 373         0       1  male  22.00      0      0  135.6333        C  NaN
# 97          1       1  male  23.00      0      1   63.3583        C    D

# %%
df
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 305         1       1    male   0.92      1      2  151.5500        S    C
# 445         1       1    male   4.00      0      2   81.8583        S    A
# 802         1       1    male  11.00      1      2  120.0000        S    B
# 550         1       1    male  17.00      0      2  110.8833        C    C
# 505         0       1    male  18.00      1      0  108.9000        C    C
# 27          0       1    male  19.00      3      2  263.0000        S    C
# 748         0       1    male  19.00      1      0   53.1000        S    D
# 102         0       1    male  21.00      0      1   77.2875        S    D
# 373         0       1    male  22.00      0      0  135.6333        C  NaN
# 97          1       1    male  23.00      0      1   63.3583        C    D
# 118         0       1    male  24.00      0      1  247.5208        C    B
# ...

# %%
df.iloc[0:20,:]
# Out:
#      survived  pclass   sex    age  sibsp  parch      fare embarked deck
# 305         1       1  male   0.92      1      2  151.5500        S    C
# 445         1       1  male   4.00      0      2   81.8583        S    A
# 802         1       1  male  11.00      1      2  120.0000        S    B
# 550         1       1  male  17.00      0      2  110.8833        C    C
# 505         0       1  male  18.00      1      0  108.9000        C    C
# 27          0       1  male  19.00      3      2  263.0000        S    C
# 748         0       1  male  19.00      1      0   53.1000        S    D
# 102         0       1  male  21.00      0      1   77.2875        S    D
# 373         0       1  male  22.00      0      0  135.6333        C  NaN
# 97          1       1  male  23.00      0      1   63.3583        C    D
# 118         0       1  male  24.00      0      1  247.5208        C    B
# 139         0       1  male  24.00      0      0   79.2000        C    B
# ...

# %%
pd.options.display.max_rows = 60

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#      index  survived  pclass     sex    age  sibsp  parch      fare embarked  \
# 0      305         1       1    male   0.92      1      2  151.5500        S
# 1      445         1       1    male   4.00      0      2   81.8583        S
# 2      802         1       1    male  11.00      1      2  120.0000        S
# 3      550         1       1    male  17.00      0      2  110.8833        C
# 4      505         0       1    male  18.00      1      0  108.9000        C
# ..     ...       ...     ...     ...    ...    ...    ...       ...      ...
# 886    697         1       3  female    NaN      0      0    7.7333        Q
# 887    727         1       3  female    NaN      0      0    7.7375        Q
# 888    792         0       3  female    NaN      8      2   69.5500        S
# 889    863         0       3  female    NaN      8      2   69.5500        S
# 890    888         0       3  female    NaN      1      2   23.4500        S
#
#     deck
# 0      C
# 1      A
# 2      B
# ...

# %%
df.drop(columns = 'index', inplace = True)

# %%
df
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 0           1       1    male   0.92      1      2  151.5500        S    C
# 1           1       1    male   4.00      0      2   81.8583        S    A
# 2           1       1    male  11.00      1      2  120.0000        S    B
# 3           1       1    male  17.00      0      2  110.8833        C    C
# 4           0       1    male  18.00      1      0  108.9000        C    C
# ..        ...     ...     ...    ...    ...    ...       ...      ...  ...
# 886         1       3  female    NaN      0      0    7.7333        Q  NaN
# 887         1       3  female    NaN      0      0    7.7375        Q  NaN
# 888         0       3  female    NaN      8      2   69.5500        S  NaN
# 889         0       3  female    NaN      8      2   69.5500        S  NaN
# 890         0       3  female    NaN      1      2   23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
df.drop(['deck'], axis = 1)
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked
# 0           1       1    male   0.92      1      2  151.5500        S
# 1           1       1    male   4.00      0      2   81.8583        S
# 2           1       1    male  11.00      1      2  120.0000        S
# 3           1       1    male  17.00      0      2  110.8833        C
# 4           0       1    male  18.00      1      0  108.9000        C
# ..        ...     ...     ...    ...    ...    ...       ...      ...
# 886         1       3  female    NaN      0      0    7.7333        Q
# 887         1       3  female    NaN      0      0    7.7375        Q
# 888         0       3  female    NaN      8      2   69.5500        S
# 889         0       3  female    NaN      8      2   69.5500        S
# 890         0       3  female    NaN      1      2   23.4500        S
#
# [891 rows x 8 columns]

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.agg(['mean','median','std','var'])
# Out:
# /var/folders/np/z13y5s3n2jlc7d6fgfm132gm0000gn/T/ipykernel_60456/1397780733.py:1: FutureWarning: ['sex', 'embarked', 'deck'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.agg(['mean','median','std','var'])
#         survived    pclass         age     sibsp     parch         fare
# mean    0.383838  2.308642   29.699118  0.523008  0.381594    32.204208
# median  0.000000  3.000000   28.000000  0.000000  0.000000    14.454200
# std     0.486592  0.836071   14.526497  1.102743  0.806057    49.693429
# var     0.236772  0.699015  211.019125  1.216043  0.649728  2469.436846

# %%
df.agg({'survived':'mean','age':['min','max'],'fare':['min','max'],'parch':'sum'})
# Out:
#       survived    age      fare  parch
# mean  0.383838    NaN       NaN    NaN
# min        NaN   0.42    0.0000    NaN
# max        NaN  80.00  512.3292    NaN
# sum        NaN    NaN       NaN  340.0

# %%
df
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 0           1       1    male   0.92      1      2  151.5500        S    C
# 1           1       1    male   4.00      0      2   81.8583        S    A
# 2           1       1    male  11.00      1      2  120.0000        S    B
# 3           1       1    male  17.00      0      2  110.8833        C    C
# 4           0       1    male  18.00      1      0  108.9000        C    C
# ..        ...     ...     ...    ...    ...    ...       ...      ...  ...
# 886         1       3  female    NaN      0      0    7.7333        Q  NaN
# 887         1       3  female    NaN      0      0    7.7375        Q  NaN
# 888         0       3  female    NaN      8      2   69.5500        S  NaN
# 889         0       3  female    NaN      8      2   69.5500        S  NaN
# 890         0       3  female    NaN      1      2   23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
df.set_index('pclass')
# Out:
#         survived     sex    age  sibsp  parch      fare embarked deck
# pclass
# 1              1    male   0.92      1      2  151.5500        S    C
# 1              1    male   4.00      0      2   81.8583        S    A
# 1              1    male  11.00      1      2  120.0000        S    B
# 1              1    male  17.00      0      2  110.8833        C    C
# 1              0    male  18.00      1      0  108.9000        C    C
# ...          ...     ...    ...    ...    ...       ...      ...  ...
# 3              1  female    NaN      0      0    7.7333        Q  NaN
# 3              1  female    NaN      0      0    7.7375        Q  NaN
# 3              0  female    NaN      8      2   69.5500        S  NaN
# 3              0  female    NaN      8      2   69.5500        S  NaN
# 3              0  female    NaN      1      2   23.4500        S  NaN
#
# [891 rows x 8 columns]

# %%
df.set_index('pclass', inplace = True)

# %%
df
# Out:
#         survived     sex    age  sibsp  parch      fare embarked deck
# pclass
# 1              1    male   0.92      1      2  151.5500        S    C
# 1              1    male   4.00      0      2   81.8583        S    A
# 1              1    male  11.00      1      2  120.0000        S    B
# 1              1    male  17.00      0      2  110.8833        C    C
# 1              0    male  18.00      1      0  108.9000        C    C
# ...          ...     ...    ...    ...    ...       ...      ...  ...
# 3              1  female    NaN      0      0    7.7333        Q  NaN
# 3              1  female    NaN      0      0    7.7375        Q  NaN
# 3              0  female    NaN      8      2   69.5500        S  NaN
# 3              0  female    NaN      8      2   69.5500        S  NaN
# 3              0  female    NaN      1      2   23.4500        S  NaN
#
# [891 rows x 8 columns]

# %%
df.iloc[[1],:]
# Out:
#         survived   sex  age  sibsp  parch     fare embarked deck
# pclass
# 1              1  male  4.0      0      2  81.8583        S    A

# %%
df.loc[1,:]
# Out:
#         survived     sex    age  sibsp  parch      fare embarked deck
# pclass
# 1              1    male   0.92      1      2  151.5500        S    C
# 1              1    male   4.00      0      2   81.8583        S    A
# 1              1    male  11.00      1      2  120.0000        S    B
# 1              1    male  17.00      0      2  110.8833        C    C
# 1              0    male  18.00      1      0  108.9000        C    C
# ...          ...     ...    ...    ...    ...       ...      ...  ...
# 1              1  female    NaN      1      0  133.6500        S  NaN
# 1              1  female    NaN      1      0   82.1708        C  NaN
# 1              1  female    NaN      1      0   51.8625        S    D
# 1              1  female    NaN      1      0   52.0000        S    C
# 1              1  female    NaN      1      0   89.1042        C    C
#
# [216 rows x 8 columns]

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.set_index(['pclass','sex'], inplace = True)

# %%
df
# Out:
#                survived   age  sibsp  parch     fare embarked deck
# pclass sex
# 3      male           0  22.0      1      0   7.2500        S  NaN
# 1      female         1  38.0      1      0  71.2833        C    C
# 3      female         1  26.0      0      0   7.9250        S  NaN
# 1      female         1  35.0      1      0  53.1000        S    C
# 3      male           0  35.0      0      0   8.0500        S  NaN
# ...                 ...   ...    ...    ...      ...      ...  ...
# 2      male           0  27.0      0      0  13.0000        S  NaN
# 1      female         1  19.0      0      0  30.0000        S    B
# 3      female         0   NaN      1      2  23.4500        S  NaN
# 1      male           1  26.0      0      0  30.0000        C    C
# 3      male           0  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 7 columns]

# %%
df.sort_index(inplace = True)

# %%
df
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
# 3      male           0  19.0      0      0    7.8958        S  NaN
#        male           0   NaN      0      0    7.8958        S  NaN
#        male           0  33.0      0      0    7.8958        S  NaN
#        male           0  25.0      0      0    7.0500        S  NaN
#        male           0  32.0      0      0    7.7500        Q  NaN
#
# [891 rows x 7 columns]

# %%
df.loc[1,'female']
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
#        female         1  45.0      1      1  164.8667        S  NaN
#        female         1  48.0      0      0   25.9292        S    D
#        female         1  47.0      1      1   52.5542        S    D
#        female         1  56.0      0      1   83.1583        C    C
#        female         1  19.0      0      0   30.0000        S    B
#
# [94 rows x 7 columns]

# %%
df
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
# 3      male           0  19.0      0      0    7.8958        S  NaN
#        male           0   NaN      0      0    7.8958        S  NaN
#        male           0  33.0      0      0    7.8958        S  NaN
#        male           0  25.0      0      0    7.0500        S  NaN
#        male           0  32.0      0      0    7.7500        Q  NaN
#
# [891 rows x 7 columns]

# %%
df.set_index('survived')
# Out:
#            age  sibsp  parch      fare embarked deck
# survived
# 1         38.0      1      0   71.2833        C    C
# 1         35.0      1      0   53.1000        S    C
# 1         58.0      0      0   26.5500        S    C
# 1          NaN      1      0  146.5208        C    B
# 1         49.0      1      0   76.7292        C    D
# ...        ...    ...    ...       ...      ...  ...
# 0         19.0      0      0    7.8958        S  NaN
# 0          NaN      0      0    7.8958        S  NaN
# 0         33.0      0      0    7.8958        S  NaN
# 0         25.0      0      0    7.0500        S  NaN
# 0         32.0      0      0    7.7500        Q  NaN
#
# [891 rows x 6 columns]

# %%
df
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        female         1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
# 3      male           0  19.0      0      0    7.8958        S  NaN
#        male           0   NaN      0      0    7.8958        S  NaN
#        male           0  33.0      0      0    7.8958        S  NaN
#        male           0  25.0      0      0    7.0500        S  NaN
#        male           0  32.0      0      0    7.7500        Q  NaN
#
# [891 rows x 7 columns]

# %%
df.swaplevel()
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# sex    pclass
# female 1              1  38.0      1      0   71.2833        C    C
#        1              1  35.0      1      0   53.1000        S    C
#        1              1  58.0      0      0   26.5500        S    C
#        1              1   NaN      1      0  146.5208        C    B
#        1              1  49.0      1      0   76.7292        C    D
# ...                 ...   ...    ...    ...       ...      ...  ...
# male   3              0  19.0      0      0    7.8958        S  NaN
#        3              0   NaN      0      0    7.8958        S  NaN
#        3              0  33.0      0      0    7.8958        S  NaN
#        3              0  25.0      0      0    7.0500        S  NaN
#        3              0  32.0      0      0    7.7500        Q  NaN
#
# [891 rows x 7 columns]

# %%
df.set_index(['pclass','sex','survived'], inplace = True)

# %%
df
# Out:
#                          age  sibsp  parch     fare embarked deck
# pclass sex    survived
# 3      male   0         22.0      1      0   7.2500        S  NaN
# 1      female 1         38.0      1      0  71.2833        C    C
# 3      female 1         26.0      0      0   7.9250        S  NaN
# 1      female 1         35.0      1      0  53.1000        S    C
# 3      male   0         35.0      0      0   8.0500        S  NaN
# ...                      ...    ...    ...      ...      ...  ...
# 2      male   0         27.0      0      0  13.0000        S  NaN
# 1      female 1         19.0      0      0  30.0000        S    B
# 3      female 0          NaN      1      2  23.4500        S  NaN
# 1      male   1         26.0      0      0  30.0000        C    C
# 3      male   0         32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 6 columns]

# %%
df.swaplevel()
# Out:
#                          age  sibsp  parch     fare embarked deck
# pclass survived sex
# 3      0        male    22.0      1      0   7.2500        S  NaN
# 1      1        female  38.0      1      0  71.2833        C    C
# 3      1        female  26.0      0      0   7.9250        S  NaN
# 1      1        female  35.0      1      0  53.1000        S    C
# 3      0        male    35.0      0      0   8.0500        S  NaN
# ...                      ...    ...    ...      ...      ...  ...
# 2      0        male    27.0      0      0  13.0000        S  NaN
# 1      1        female  19.0      0      0  30.0000        S    B
# 3      0        female   NaN      1      2  23.4500        S  NaN
# 1      1        male    26.0      0      0  30.0000        C    C
# 3      0        male    32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 6 columns]

# %%
df
# Out:
#                          age  sibsp  parch     fare embarked deck
# pclass sex    survived
# 3      male   0         22.0      1      0   7.2500        S  NaN
# 1      female 1         38.0      1      0  71.2833        C    C
# 3      female 1         26.0      0      0   7.9250        S  NaN
# 1      female 1         35.0      1      0  53.1000        S    C
# 3      male   0         35.0      0      0   8.0500        S  NaN
# ...                      ...    ...    ...      ...      ...  ...
# 2      male   0         27.0      0      0  13.0000        S  NaN
# 1      female 1         19.0      0      0  30.0000        S    B
# 3      female 0          NaN      1      2  23.4500        S  NaN
# 1      male   1         26.0      0      0  30.0000        C    C
# 3      male   0         32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 6 columns]

# %%
df.sort_index()
# Out:
#                          age  sibsp  parch      fare embarked deck
# pclass sex    survived
# 1      female 0         50.0      0      0   28.7125        C    C
#               0          2.0      1      2  151.5500        S    C
#               0         25.0      1      2  151.5500        S    C
#               1         38.0      1      0   71.2833        C    C
#               1         35.0      1      0   53.1000        S    C
# ...                      ...    ...    ...       ...      ...  ...
# 3      male   1         27.0      0      0    6.9750        S  NaN
#               1         27.0      0      0    8.6625        S  NaN
#               1          NaN      0      0    7.7500        Q  NaN
#               1         32.0      0      0   56.4958        S  NaN
#               1          4.0      1      1   11.1333        S  NaN
#
# [891 rows x 6 columns]
